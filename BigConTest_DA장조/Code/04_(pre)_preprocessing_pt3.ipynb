# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta, time
import re
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import shapiro, zscore
from matplotlib.colors import LinearSegmentedColormap

import gzip
import pickle

# %matplotlib inline


# matplotlib 한글 깨짐 해결
from matplotlib import rc

rc('font', family='NanumGothic')
plt.rcParams['axes.unicode_minus'] = False

# %%
df = pd.read_csv('../processed_v2.csv')
df.head()
# Out:
#     age gender  tran_date tran_time  play_date play_st_time         seat  \
# 0  50.0      F   20220114     15:12   20220204        20:00   3층 BOX9 10
# 1  50.0      M   20220206     16:15   20220302        19:30  1층 B블록12열 7
# 2  30.0      F   20181124     11:45   20190323        20:00   1층 A블록2열 1
# 3   NaN    NaN   20190613     09:54   20190723        20:00   2층 D블록8열 4
# 4   NaN      F   20190703     09:08   20190721        17:00  1층 C블록17열 3
#
#     price  ticket_cancel discount_type  ...  inv2_paymem_cnt  inv4_buyyn  \
# 0   10000              2            일반  ...                2           1
# 1  180000              0            일반  ...                0           1
# 2  144000              2    블루회원 할인20%  ...                1           1
# 3       0              0           초대권  ...                0           0
# 4   75000              0            일반  ...                1           1
#
#   involvement  seat_floor  seat_loc seat_gen  cancel_rate  paid_rate  \
# 0           4       third      left        B     0.172237   0.996144
# 1           2       first      left        R     0.244957   0.968300
# 2           3       first      left        B     0.167689   0.991820
# 3           0      second     right        A     0.004285   0.028388
# 4           3       first       mid        R     0.044788   0.348534
#
#    pre_rate  capa_rate
# 0       0.0   0.257086
# 1       0.0   0.522954
# 2       0.0   0.649900
# 3       0.0   0.742116
# 4       0.0   0.525773
#
# [5 rows x 45 columns]

# %% [markdown]
#         howfastyoubuy 변수 생성

# %%
df['tran_date'] = pd.to_datetime(df['tran_date'], format='%Y%m%d') # 고객 구매날짜
df['play_date'] = pd.to_datetime(df['play_date'], format='%Y%m%d') # 공연날짜
df['open_date'] = pd.to_datetime(df['open_date'], format='%Y%m%d') # 예매일

# 선예매날짜
df['pre_open_date'] = df['pre_open_date'].replace(0, pd.NA)
df['pre_open_date'] = pd.to_datetime(df['pre_open_date'], format='%Y%m%d')

# %%
final = df.copy()
#howfastyoubuy 변수 생성
final = final.assign(howfastyoubuy=(final['tran_date'] - final['play_date']).dt.days)

# %%
# 구매일이 선예매일자보다 빠른 데이터만 추출
df = df[df['tran_date'] < df['pre_open_date']]
# 초대권이나 기획사 판매인 경우, 제외
new = df[~df['discount_type'].isin(['초대권', '기획사판매'])]
new
# Out:
#          age gender  tran_date tran_time  play_date play_st_time         seat  \
# 315     60.0      F 2019-07-26     11:02 2019-09-10        20:00   1층 C블록4열 2
# 533     50.0      F 2022-07-11     15:03 2022-10-11        19:30   2층 A블록5열 9
# 1098    60.0      F 2019-12-08     12:21 2020-10-01        20:00  3층 N블록1열 15
# 1559    60.0      F 2020-06-18     15:33 2020-12-12        17:00  1층 C블록17열 9
# 1691    50.0      M 2019-12-08     11:17 2020-10-01        20:00   1층 E블록1열 5
# ...      ...    ...        ...       ...        ...          ...          ...
# 751005  50.0      M 2020-05-30     18:58 2020-07-26        17:00  1층 C블록7열 11
# 751167  50.0      M 2019-07-14     14:25 2019-09-01        17:00  1층 D블록10열 3
# 751259  50.0      F 2022-10-30     17:43 2022-12-27        20:00  1층 A블록9열 11
# 752354  50.0      F 2018-11-10     23:55 2019-01-11        20:00   1층 A블록3열 4
# 752839  40.0      F 2020-04-20     09:03 2020-10-23        20:00   1층 A블록2열 3
#
#          price  ticket_cancel             discount_type  ... inv2_paymem_cnt  \
# 315      21000              0                골드회원 할인30%  ...               1
# 533      30000              0                        일반  ...               1
# 1098     10000              2                        일반  ...               1
# 1559     81000              2                골드회원 할인10%  ...               2
# 1691     18000              2                골드회원 할인10%  ...               1
# ...        ...            ...                       ...  ...             ...
# 751005   42000              0                골드회원 할인30%  ...               1
# 751167   10000              0          초/중/고등학생 할인(본인만)  ...               1
# 751259  127000              0  조기예매할인(1인1매/~11월3일까지)25%  ...               1
# 752354  100000              0                        일반  ...               1
# 752839   20000              2                        일반  ...               0
#
#        inv4_buyyn involvement  seat_floor  seat_loc seat_gen  cancel_rate  \
# 315             1           3       first       mid        R     0.051530
# 533             1           3      second      left        A     0.300353
# 1098            1           3       third     right        C     0.949495
# 1559            1           4       first       mid        R     0.943299
# 1691            1           3       first     right        A     0.949495
# ...           ...         ...         ...       ...      ...          ...
# 751005          1           3       first       mid        R     0.483209
# 751167          1           3       first     right        R     0.100000
# 751259          1           3       first      left        S     0.063908
# 752354          1           3       first      left        A     0.112031
# 752839          1           2       first      left        B     0.441026
#
#         paid_rate  pre_rate  capa_rate
# 315      0.486312  0.012882   0.235130
# 533      1.000000  0.000000   0.158084
# 1098     1.000000  0.000000   0.007987
# 1559     1.000000  0.000000   0.026358
# 1691     1.000000  0.000000   0.007987
# ...           ...       ...        ...
# 751005   1.000000  0.000000   0.221246
# 751167   1.000000  0.070652   0.330539
# 751259   0.382923  0.000000   0.713373
# 752354   0.611076  0.000637   0.556886
# 752839   1.000000  0.000000   0.146571
#
# [2115 rows x 45 columns]

# %%
# pre_ticketing 값에 따라 tran_date 열의 값을 변경
new.loc[new['pre_ticketing'] == 1, 'tran_date'] = new['pre_open_date']
new.loc[new['pre_ticketing'] == 0, 'tran_date'] = new['open_date']

# %%
# 얼마나 빨리 예매했는지 수치 계산(howfastyoubuy 변수 생성)
new = new.assign(howfastyoubuy=(new['tran_date'] - new['play_date']).dt.days)
new
# Out:
#          age gender  tran_date tran_time  play_date play_st_time         seat  \
# 315     60.0      F 2019-08-02     11:02 2019-09-10        20:00   1층 C블록4열 2
# 533     50.0      F 2022-07-16     15:03 2022-10-11        19:30   2층 A블록5열 9
# 1098    60.0      F 2020-08-22     12:21 2020-10-01        20:00  3층 N블록1열 15
# 1559    60.0      F 2020-11-08     15:33 2020-12-12        17:00  1층 C블록17열 9
# 1691    50.0      M 2020-08-22     11:17 2020-10-01        20:00   1층 E블록1열 5
# ...      ...    ...        ...       ...        ...          ...          ...
# 751005  50.0      M 2020-07-18     18:58 2020-07-26        17:00  1층 C블록7열 11
# 751167  50.0      M 2019-07-19     14:25 2019-09-01        17:00  1층 D블록10열 3
# 751259  50.0      F 2022-10-30     17:43 2022-12-27        20:00  1층 A블록9열 11
# 752354  50.0      F 2018-12-10     23:55 2019-01-11        20:00   1층 A블록3열 4
# 752839  40.0      F 2020-09-26     09:03 2020-10-23        20:00   1층 A블록2열 3
#
#          price  ticket_cancel             discount_type  ... inv4_buyyn  \
# 315      21000              0                골드회원 할인30%  ...          1
# 533      30000              0                        일반  ...          1
# 1098     10000              2                        일반  ...          1
# 1559     81000              2                골드회원 할인10%  ...          1
# 1691     18000              2                골드회원 할인10%  ...          1
# ...        ...            ...                       ...  ...        ...
# 751005   42000              0                골드회원 할인30%  ...          1
# 751167   10000              0          초/중/고등학생 할인(본인만)  ...          1
# 751259  127000              0  조기예매할인(1인1매/~11월3일까지)25%  ...          1
# 752354  100000              0                        일반  ...          1
# 752839   20000              2                        일반  ...          1
#
#        involvement seat_floor  seat_loc  seat_gen cancel_rate  paid_rate  \
# 315              3      first       mid         R    0.051530   0.486312
# 533              3     second      left         A    0.300353   1.000000
# 1098             3      third     right         C    0.949495   1.000000
# 1559             4      first       mid         R    0.943299   1.000000
# 1691             3      first     right         A    0.949495   1.000000
# ...            ...        ...       ...       ...         ...        ...
# 751005           3      first       mid         R    0.483209   1.000000
# 751167           3      first     right         R    0.100000   1.000000
# 751259           3      first      left         S    0.063908   0.382923
# 752354           3      first      left         A    0.112031   0.611076
# 752839           2      first      left         B    0.441026   1.000000
#
#         pre_rate  capa_rate  howfastyoubuy
# 315     0.012882   0.235130            -39
# 533     0.000000   0.158084            -87
# 1098    0.000000   0.007987            -40
# 1559    0.000000   0.026358            -34
# 1691    0.000000   0.007987            -40
# ...          ...        ...            ...
# 751005  0.000000   0.221246             -8
# 751167  0.070652   0.330539            -44
# 751259  0.000000   0.713373            -58
# 752354  0.000637   0.556886            -32
# 752839  0.000000   0.146571            -27
#
# [2115 rows x 46 columns]

# %%
# 인덱스를 기반으로 df를 new의 값으로 업데이트
final.update(new)

# %%
final.groupby(['new_code'])['howfastyoubuy'].mean().describe()
# Out:
# count    670.000000
# mean     -30.383681
# std       26.607020
# min     -245.869115
# 25%      -35.018870
# 50%      -22.847764
# 75%      -15.077132
# max       -4.016626
# Name: howfastyoubuy, dtype: float64

# %%
# describe를 통해 50%값보기
mapping = final.groupby('new_code')['howfastyoubuy'].describe().reset_index()
mapping = mapping[['new_code', '50%']]
mapping
# Out:
#      new_code   50%
# 0           0  -9.0
# 1           1 -20.0
# 2           2 -31.0
# 3           5 -17.0
# 4           6 -32.0
# ..        ...   ...
# 665       745 -43.0
# 666       746 -37.0
# 667       747 -55.0
# 668       748 -58.0
# 669       750 -36.0
#
# [670 rows x 2 columns]

# %%
# 데이터프레임 merge
merged_df = final.merge(mapping, on='new_code', how='left')

# 계산하기 쉽게 양수로 변경
merged_df['plushowfastyoubuy'] = merged_df['howfastyoubuy'] * -1
merged_df['plus50%'] = merged_df['50%'] * -1

# %%
# 50%이하인 값 보기
real = merged_df[merged_df['plushowfastyoubuy'] <= merged_df['plus50%']]
real
# Out:
#          age gender  tran_date tran_time  play_date play_st_time  \
# 1       50.0      M 2022-02-06     16:15 2022-03-02        19:30
# 2       30.0      F 2018-11-24     11:45 2019-03-23        20:00
# 3        NaN    NaN 2019-06-13     09:54 2019-07-23        20:00
# 6        NaN    NaN 2022-06-24     16:18 2022-06-29        19:30
# 7        NaN    NaN 2020-05-11     09:14 2020-05-15        19:30
# ...      ...    ...        ...       ...        ...          ...
# 753447  30.0      F 2023-05-16     17:43 2023-06-03        17:00
# 753449  60.0      F 2021-06-18     15:09 2021-07-04        15:00
# 753450  50.0      M 2023-05-22     17:29 2023-06-13        17:00
# 753451   NaN    NaN 2020-10-09     16:52 2020-10-20        19:30
# 753452   NaN    NaN 2020-07-26     16:55 2020-08-18        19:30
#
#                 seat   price  ticket_cancel discount_type  ... seat_loc  \
# 1        1층 B블록12열 7  180000              0            일반  ...     left
# 2         1층 A블록2열 1  144000              2    블루회원 할인20%  ...     left
# 3         2층 D블록8열 4       0              0           초대권  ...    right
# 6         3층 BOX12 3   20000              2            일반  ...    right
# 7        2층 E블록3열 16       0              0           초대권  ...    right
# ...              ...     ...            ...           ...  ...      ...
# 753447    3층 D블록6열 6   40000              0            일반  ...      mid
# 753449    1층 A블록2열 2   90000              2            일반  ...     left
# 753450    3층 A블록6열 4   10000              0            일반  ...     left
# 753451  1층 D블록16열 12       0              0           초대권  ...    right
# 753452   1층 D블록20열 8       0              0         기획사판매  ...    right
#
#        seat_gen cancel_rate  paid_rate  pre_rate capa_rate  howfastyoubuy  \
# 1             R    0.244957   0.968300  0.000000  0.522954            -24
# 2             B    0.167689   0.991820  0.000000  0.649900           -119
# 3             A    0.004285   0.028388  0.000000  0.742116            -40
# 6             B    0.036993   0.202864  0.000000  0.322156             -5
# 7             B    0.034934   0.154710  0.008734  1.000000             -4
# ...         ...         ...        ...       ...       ...            ...
# 753447        C    0.098361   0.742176  0.000000  0.483034            -18
# 753449        B    0.396887   0.996109  0.003891  0.247604            -16
# 753450        C    0.011291   0.732941  0.019146  0.902734            -22
# 753451        R    0.031766   0.246506  0.000000  0.341551            -11
# 753452        S    0.001638   0.019656  0.000000  0.973642            -23
#
#           50%  plushowfastyoubuy  plus50%
# 1       -50.0                 24     50.0
# 2      -123.0                119    123.0
# 3       -40.0                 40     40.0
# 6        -5.0                  5      5.0
# 7        -4.0                  4      4.0
# ...       ...                ...      ...
# 753447  -21.0                 18     21.0
# 753449  -16.0                 16     16.0
# 753450  -25.0                 22     25.0
# 753451  -11.0                 11     11.0
# 753452  -23.0                 23     23.0
#
# [514803 rows x 49 columns]

# %%
# 데이터 별로 mean값 구하기
new_gen = real.groupby(['new_code', 'seat_gen'])['howfastyoubuy'].agg(['mean']).reset_index()
new_loc = real.groupby(['new_code', 'seat_loc'])['howfastyoubuy'].agg(['mean']).reset_index()
new_floor = real.groupby(['new_code', 'seat_floor'])['howfastyoubuy'].agg(['mean']).reset_index()

# gen_gen = real.groupby(['genre', 'seat_gen'])['howfastyoubuy'].agg(['mean']).reset_index()
# gen_loc = real.groupby(['genre', 'seat_loc'])['howfastyoubuy'].agg(['mean']).reset_index()
# gen_floor = real.groupby(['genre', 'seat_floor'])['howfastyoubuy'].agg(['mean']).reset_index()

# %%
# 컬럼명 변경
new_gen = new_gen.rename(columns={'mean': 'newseatgen_mean'})
new_loc = new_loc.rename(columns={'mean': 'newseatloc_mean'})
new_floor = new_floor.rename(columns={'mean': 'newfloorloc_mean'})
# gen_gen = gen_gen.rename(columns={'mean': 'genre_gen_mean'})
# gen_loc = gen_loc.rename(columns={'mean': 'genre_loc_mean'})
# gen_floor =gen_floor.rename(columns={'mean': 'genre_floor_mean'})

# %%
#데이터 합치기
matched_df = merged_df.merge(new_gen, on=['new_code', 'seat_gen'], how='left')
md2 = matched_df.merge(new_loc,on=['new_code', 'seat_loc'], how='left' )
md3 = md2.merge(new_floor,on=['new_code', 'seat_floor'], how='left' )
# md4 = md3.merge(gen_gen,on=['genre', 'seat_gen'], how='left' )
# md5 = md4.merge(gen_loc,on=['genre', 'seat_loc'], how='left' )
# md6 = md5.merge(gen_floor,on=['genre', 'seat_floor'], how='left' )

# %% [markdown]
#         확인

# %%
check = md3[['new_code', 'genre', 'seat_floor','howfastyoubuy','newseatgen_mean', 'newseatloc_mean', 'newfloorloc_mean']]
check
# Out:
#         new_code genre seat_floor  howfastyoubuy  newseatgen_mean  \
# 0            435   교향곡      third            -21        -7.866337
# 1            449    독주      first            -24       -24.009132
# 2             31   교향곡      first           -119       -70.903101
# 3            100   교향곡     second            -40       -34.708885
# 4             99   클래식      first            -18        -5.536585
# ...          ...   ...        ...            ...              ...
# 753449       325   교향곡      first            -16       -14.660714
# 753450       732   교향곡      third            -22       -11.803571
# 753451       250   클래식      first            -11        -9.029520
# 753452       241    합창      first            -23       -21.533898
# 753453       685   교향곡      third           -105       -16.310000
#
#         newseatloc_mean  newfloorloc_mean
# 0            -10.000000        -10.752066
# 1            -31.433420        -27.927313
# 2            -71.093434        -69.510129
# 3            -30.234501        -29.536585
# 4             -5.812500         -5.581522
# ...                 ...               ...
# 753449       -14.306306        -14.878571
# 753450       -14.924956        -11.508772
# 753451        -7.227437         -8.135524
# 753452       -22.644820        -20.560132
# 753453       -16.244565        -16.008130
#
# [753454 rows x 7 columns]

# %%
zero = check[check['new_code'] == 0]
pd.crosstab(zero.seat_floor, zero.newfloorloc_mean)
# Out:
# newfloorloc_mean  -8.675676  -7.780000  -7.705882
# seat_floor
# first                     0          0       1209
# second                    0        281          0
# third                    47          0          0

# %%
new_floor[new_floor['new_code'] == 0]
# Out:
#    new_code seat_floor  newfloorloc_mean
# 0         0      first         -7.705882
# 1         0     second         -7.780000
# 2         0      third         -8.675676

# %%
md3['pre_open_date'].isna().sum()
# Out:
# 254853

# %%
# pre_open_date(null 값)를 0으로 채우기
md3['pre_open_date'].fillna(0, inplace=True)
md3[md3.pre_open_date.isnull()]
# Out:
# Empty DataFrame
# Columns: [age, gender, tran_date, tran_time, play_date, play_st_time, seat, price, ticket_cancel, discount_type, pre_open_date, open_date, genre, running_time, intermission, member_yn, new_code, key, pre_ticketing, general, sac, noble, discount_rate, real_price, discount_cat, all_mem_cnt, blue, green, gold, play_date_dt, season, performance_time_slot, day_of_week, weekday_or_weekend, inv1_memyn, inv2_paymem_cnt, inv4_buyyn, involvement, seat_floor, seat_loc, seat_gen, cancel_rate, paid_rate, pre_rate, capa_rate, howfastyoubuy, 50%, plushowfastyoubuy, plus50%, newseatgen_mean, newseatloc_mean, newfloorloc_mean]
# Index: []
#
# [0 rows x 52 columns]

# %%
# 전처리 항목 추가 (running_time보다 intermission이 긴 경우 (3개 공연, 1477개))
md3 = md3[md3['running_time']>md3['intermission']]
md3.shape
# Out:
# (751977, 52)

# %%
md3 = md3[['key', 'new_code', 'age', 'gender', 'tran_date', 'tran_time', 'play_date', 'play_st_time',
       'seat', 'price', 'ticket_cancel', 'discount_type', 'pre_open_date', 'open_date', 'genre', 'running_time', 
       'intermission', 'member_yn','pre_ticketing', 'general', 'sac', 'noble', 'green', 'blue', 'gold',
       'discount_rate', 'real_price', 'discount_cat', 'all_mem_cnt', 'season', 'performance_time_slot',
       'day_of_week', 'weekday_or_weekend', 'inv1_memyn', 'inv2_paymem_cnt', 'inv4_buyyn', 'involvement', 
       'seat_floor', 'seat_loc', 'seat_gen', 'cancel_rate', 'paid_rate', 'pre_rate', 'capa_rate', 'howfastyoubuy',
       '50%', 'newseatgen_mean', 'newseatloc_mean', 'newfloorloc_mean']]

# %% [markdown]
#         저장

# %%
md3.to_csv('/home/finda/final/data/final_data.csv', index=False)
