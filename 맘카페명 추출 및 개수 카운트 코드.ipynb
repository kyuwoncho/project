# %%
# !pip install konlpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 19.4 MB 8.2 MB/s
# ...
#      |████████████████████████████████| 453 kB 71.1 MB/s
# ...

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
import nltk 
from konlpy.tag import Kkma
from konlpy.tag import Twitter
from wordcloud import WordCloud

# %%
# !apt-get update -qq
# !apt-get install fonts-nanum* -qq  #코랩에서 한글 표기를 위해 폰트 설치(리눅스)
# Out:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 155639 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20170925-1_all.deb ...
# Unpacking fonts-nanum (20170925-1) ...
# Selecting previously unselected package fonts-nanum-eco.
# Preparing to unpack .../fonts-nanum-eco_1.000-6_all.deb ...
# Unpacking fonts-nanum-eco (1.000-6) ...
# Selecting previously unselected package fonts-nanum-extra.
# Preparing to unpack .../fonts-nanum-extra_20170925-1_all.deb ...
# Unpacking fonts-nanum-extra (20170925-1) ...
# Selecting previously unselected package fonts-nanum-coding.
# Preparing to unpack .../fonts-nanum-coding_2.5-1_all.deb ...
# Unpacking fonts-nanum-coding (2.5-1) ...
# Setting up fonts-nanum-extra (20170925-1) ...
# Setting up fonts-nanum (20170925-1) ...
# Setting up fonts-nanum-coding (2.5-1) ...
# Setting up fonts-nanum-eco (1.000-6) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...

# %%
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import urllib.request
from collections import Counter
from konlpy.tag import Mecab
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import pandas as pd
import numpy as np
import pickle
from pprint import pprint
import re
#from wordcloud import WordCloud

from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Mounted at /content/drive/

# %%
import os
path ="/content/drive/Shareddrives/흐사드/가공데이터/sometrend_제외어_및_포함어_원문/아로나민골드_원문_최종/"
target_list=os.listdir(path)
target_list
# Out:
# ['커뮤니티 빈도분석',
#  '아로나민골드, 그 외_원문_20180101_20180131.xlsx',
#  '타겟분석_원문_20180101_20180131.xlsx',
#  '타겟분석_원문_20180101_20180131 (1).xlsx',
#  '타겟분석_원문_20180101_20180131 (3).xlsx',
#  '타겟분석_원문_20180101_20180131 (4).xlsx',
#  '타겟분석_원문_20180101_20180131 (5).xlsx',
#  '아로나민골드, 그 외_원문_20180201_20180228.xlsx',
#  '타겟분석_원문_20180201_20180228.xlsx',
#  '타겟분석_원문_20180201_20180228 (1).xlsx',
#  '타겟분석_원문_20180201_20180228 (2).xlsx',
#  '타겟분석_원문_20180201_20180228 (3).xlsx',
#  '타겟분석_원문_20180201_20180228 (4).xlsx',
#  '타겟분석_원문_20180201_20180228 (6).xlsx',
#  '아로나민골드, 그 외_원문_20180301_20180331.xlsx',
#  '타겟분석_원문_20180301_20180331.xlsx',
#  '타겟분석_원문_20180301_20180331 (1).xlsx',
#  '타겟분석_원문_20180301_20180331 (2).xlsx',
#  '타겟분석_원문_20180301_20180331 (3).xlsx',
# ...

# %%
target_list.remove( '아로나민골드, 그 외_원문_20191001_20191031.xlsx')
target_list.remove('아로나민골드, 그 외_원문_20190201_20190228.xlsx')
target_list.remove( '아로나민골드, 그 외_원문_20190101_20190131.xlsx')
target_list.remove(  '아로나민골드, 그 외_원문_20181001_20181031.xlsx')
target_list.remove(  '아로나민골드, 그 외_원문_20210501_20210531.xlsx')
target_list.remove('아로나민골드, 그 외_원문_20210401_20210430.xlsx')
target_list.remove(  '아로나민골드, 그 외_원문_20210301_20210331.xlsx')
target_list.remove( '아로나민골드, 그 외_원문_20210201_20210228.xlsx')
target_list.remove(  '아로나민골드, 그 외_원문_20201201_20201231.xlsx')
target_list.remove('아로나민골드, 그 외_원문_20201001_20201031.xlsx')
target_list.remove( '아로나민골드, 그 외_원문_20200901_20200930.xlsx')
target_list.remove('아로나민골드, 그 외_원문_20200701_20200731.xlsx')
target_list.remove('아로나민골드, 그 외_원문_20200401_20200430.xlsx')
target_list.remove( '아로나민골드, 그 외_원문_20180901_20180930.xlsx')
target_list.remove( '아로나민골드, 그 외_원문_20190301_20190331.xlsx')
target_list.remove( '아로나민골드, 그 외_원문_20190401_20190430.xlsx')
target_list.remove( '아로나민골드, 그 외_원문_20190601_20190630.xlsx')
target_list.remove( '아로나민골드, 그 외_원문_20200201_20200228.xlsx')
target_list.remove( '아로나민골드, 그 외_원문_20200101_20200131.xlsx')
target_list.remove('아로나민골드, 그 외_원문_20200301_20200331.xlsx')
target_list.remove( '아로나민골드, 그 외_원문_20200501_20200531.xlsx')
target_list.remove('아로나민골드, 그 외_원문_20200601_20200630.xlsx')
target_list.remove('아로나민골드, 그 외_원문_20180301_20180331.xlsx')
target_list.remove( '아로나민골드, 그 외_원문_20180701_20180731.xlsx')
target_list.remove( '아로나민골드, 그 외_원문_20180801_20180831.xlsx')
target_list.remove( '아로나민골드, 그 외_원문_20190901_20190930.xlsx')
target_list.remove('아로나민골드, 그 외_원문_20190501_20190531.xlsx')
target_list.remove( '아로나민골드, 그 외_원문_20190701_20190731.xlsx')
target_list.remove('아로나민골드, 그 외_원문_20190801_20190831.xlsx')
target_list.remove('아로나민골드, 그 외_원문_20191101_20191130.xlsx')
# target_list.remove('타겟분석_엑셀.ipynb')
target_list.remove('엑셀가져오기.ipynb')
target_list.remove('아로나민골드, 그 외_원문_20220101_20220131.xlsx',)
target_list.remove('아로나민골드, 그 외_원문_20210801_20210831.xlsx')
target_list.remove( '아로나민골드, 그 외_원문_20210701_20210731.xlsx')
target_list.remove('아로나민골드, 그 외_원문_20210601_20210630.xlsx')
target_list.remove('아로나민골드, 그 외_원문_20210101_20210131.xlsx')
target_list.remove('아로나민골드, 그 외_원문_20201101_20201130.xlsx')
target_list.remove('아로나민골드, 그 외_원문_20200801_20200831.xlsx')
target_list.remove('아로나민골드, 그 외_원문_20210901_20210930.xlsx')
target_list.remove('아로나민골드, 그 외_원문_20220201_20220228.xlsx')
target_list.remove('아로나민골드, 그 외_원문_20211201_20211231.xlsx')
target_list.remove( '아로나민골드, 그 외_원문_20211101_20211130.xlsx')
target_list.remove('아로나민골드, 그 외_원문_20211001_20211031.xlsx')
target_list.remove('아로나민골드, 그 외_원문_20181201_20181231.xlsx')
target_list.remove('LDA_여성.ipynb')
target_list.remove('아로나민골드, 그 외_원문_20180101_20180131.xlsx')
target_list.remove( '아로나민골드, 그 외_원문_20180201_20180228.xlsx')
target_list.remove( '아로나민골드, 그 외_원문_20180401_20180430.xlsx')
target_list.remove('아로나민골드, 그 외_원문_20180501_20180531.xlsx')
target_list.remove('아로나민골드, 그 외_원문_20180601_20180630.xlsx')
target_list.remove( '아로나민골드, 그 외_원문_20191201_20191231.xlsx')
target_list.remove('아로나민골드, 그 외_원문_20220301_20220331.xlsx')
target_list.remove('LDA결과')
target_list.remove('LDA_타겟분석_3040.ipynb')
target_list.remove('워드클라우드')
target_list.remove('커뮤니티 빈도분석')

# %%
target_list
# Out:
# ['타겟분석_원문_20180101_20180131.xlsx',
#  '타겟분석_원문_20180101_20180131 (1).xlsx',
#  '타겟분석_원문_20180101_20180131 (3).xlsx',
#  '타겟분석_원문_20180101_20180131 (4).xlsx',
#  '타겟분석_원문_20180101_20180131 (5).xlsx',
#  '타겟분석_원문_20180201_20180228.xlsx',
#  '타겟분석_원문_20180201_20180228 (1).xlsx',
#  '타겟분석_원문_20180201_20180228 (2).xlsx',
#  '타겟분석_원문_20180201_20180228 (3).xlsx',
#  '타겟분석_원문_20180201_20180228 (4).xlsx',
#  '타겟분석_원문_20180201_20180228 (6).xlsx',
#  '타겟분석_원문_20180301_20180331.xlsx',
#  '타겟분석_원문_20180301_20180331 (1).xlsx',
#  '타겟분석_원문_20180301_20180331 (2).xlsx',
#  '타겟분석_원문_20180301_20180331 (3).xlsx',
#  '타겟분석_원문_20180301_20180331 (4).xlsx',
#  '타겟분석_원문_20180301_20180331 (5).xlsx',
#  '타겟분석_원문_20180301_20180331 (6).xlsx',
#  '타겟분석_원문_20180401_20180430.xlsx',
# ...

# %% [markdown]
# # 3040대

# %%
import openpyxl
path = '/content/drive/Shareddrives/흐사드/가공데이터/sometrend_제외어_및_포함어_원문/아로나민골드_원문_최종/'

ages= []
for i in target_list:
  a = path + i
  wb =openpyxl.load_workbook(a)
  sheet = wb.get_sheet_by_name('검색 조건')
  if sheet['C6'].value == '3040':
    ages.append(i)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: DeprecationWarning: Call to deprecated function get_sheet_by_name (Use wb[sheetname]).

# %%
ages
# Out:
# ['타겟분석_원문_20180201_20180228 (2).xlsx',
#  '타겟분석_원문_20180301_20180331 (2).xlsx',
#  '타겟분석_원문_20180401_20180430 (2).xlsx',
#  '타겟분석_원문_20180501_20180531 (2).xlsx',
#  '타겟분석_원문_20180601_20180630 (2).xlsx',
#  '타겟분석_원문_20180701_20180731 (2).xlsx',
#  '타겟분석_원문_20180801_20180831 (2).xlsx',
#  '타겟분석_원문_20180901_20180930 (2).xlsx',
#  '타겟분석_원문_20181001_20181031 (2).xlsx',
#  '타겟분석_원문_20181101_20181130 (2).xlsx',
#  '타겟분석_원문_20181201_20181231 (2).xlsx',
#  '타겟분석_원문_20190101_20190131 (2).xlsx',
#  '타겟분석_원문_20190201_20190228 (2).xlsx',
#  '타겟분석_원문_20190301_20190331 (2).xlsx',
#  '타겟분석_원문_20190401_20190430 (2).xlsx',
#  '타겟분석_원문_20190501_20190531 (2).xlsx',
#  '타겟분석_원문_20190601_20190630 (2).xlsx',
#  '타겟분석_원문_20190701_20190731 (2).xlsx',
#  '타겟분석_원문_20190801_20190831 (2).xlsx',
# ...

# %%
import openpyxl
path = '/content/drive/Shareddrives/흐사드/가공데이터/sometrend_제외어_및_포함어_원문/아로나민골드_원문_최종/'

female= []
for i in target_list:
  a = path + i
  wb =openpyxl.load_workbook(a)
  sheet = wb.get_sheet_by_name('검색 조건')
  if sheet['C6'].value == '여성':
    female.append(i)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: DeprecationWarning: Call to deprecated function get_sheet_by_name (Use wb[sheetname]).

# %%
female
# Out:
# ['타겟분석_원문_20180101_20180131 (5).xlsx',
#  '타겟분석_원문_20180301_20180331 (5).xlsx',
#  '타겟분석_원문_20180401_20180430 (5).xlsx',
#  '타겟분석_원문_20180501_20180531 (5).xlsx',
#  '타겟분석_원문_20180601_20180630 (5).xlsx',
#  '타겟분석_원문_20180701_20180731 (5).xlsx',
#  '타겟분석_원문_20180801_20180831 (5).xlsx',
#  '타겟분석_원문_20180901_20180930 (5).xlsx',
#  '타겟분석_원문_20181001_20181031 (5).xlsx',
#  '타겟분석_원문_20181101_20181130 (5).xlsx',
#  '타겟분석_원문_20181201_20181231 (5).xlsx',
#  '타겟분석_원문_20190101_20190131 (5).xlsx',
#  '타겟분석_원문_20190201_20190228 (5).xlsx',
#  '타겟분석_원문_20190301_20190331 (5).xlsx',
#  '타겟분석_원문_20190401_20190430 (5).xlsx',
#  '타겟분석_원문_20190501_20190531 (5).xlsx',
#  '타겟분석_원문_20190601_20190630 (5).xlsx',
#  '타겟분석_원문_20190701_20190731 (5).xlsx',
#  '타겟분석_원문_20190801_20190831 (5).xlsx',
# ...

# %% [markdown]
# # 공통

# %%
# !pip install konlpy

# %% [markdown]
# ### 엑셀합치기

# %% [markdown]
# ##### 3040대

# %%
path = '/content/drive/Shareddrives/흐사드/가공데이터/sometrend_제외어_및_포함어_원문/아로나민골드_원문_최종/'

list_of_ages = [] # 빈 list를 만듦.

for fname in ages:
  a=path + fname
  df_tem = pd.read_excel(a,sheet_name = '원문 - 커뮤니티')
  list_of_ages.append(df_tem) # 매 Loop에서 취해진 DataFrame을 위의 list에 적재함.
df_ages = pd.concat(list_of_ages,axis = 0, ignore_index = True) # list 속 DataFrame들을 일괄 병합함.

# %%
# df_ages.to_excel('ages.xlsx')

# %%
# df_ages.to_excel('3040대.xlsx')

# %%
# df_female.to_excel('여성.xlsx')

# %%
len(df_ages)
# Out:
# 1049

# %%
df_ages = df_ages.drop(['제목'], axis = 1)
df_ages = df_ages.drop(['작성자'], axis = 1)
df_ages = df_ages.drop(['URL'], axis = 1)
df_ages = df_ages.drop(['No.'], axis = 1)
df_ages = df_ages.drop(['날짜'], axis = 1)

# %%
df_ages=df_ages.dropna()
df_ages
# Out:
#               채널
# 0        수원맘 모여라
# 1     맘스홀릭 베이비_8
# 2         오창맘모여라
# 3           청라맘스
# 4           보배드림
# ...          ...
# 1044   전주 전북 알뜰맘
# 1045    춘천좋은엄마모임
# 1046      세종맘모여라
# 1047       파주운정맘
# 1048    분당판교따라잡기
#
# [1049 rows x 1 columns]

# %%
df_ages['채널'].value_counts()
# Out:
# MLB파크             51
# 인천맘의 아띠아모         47
# 레몬테라스             41
# 수원맘 모여라           37
# 부산맘 아기사랑          32
#                   ..
# 맘이 베베              1
# 해피 고성맘             1
# 제주맘                1
# 스사사                1
# 이혼에서 재혼까지/이재모2     1
# Name: 채널, Length: 183, dtype: int64

# %%
total_ages=df_ages
total_ages=total_ages.drop_duplicates()
total_ages
# Out:
#                   채널
# 0            수원맘 모여라
# 1         맘스홀릭 베이비_8
# 2             오창맘모여라
# 3               청라맘스
# 4               보배드림
# ...              ...
# 1002   벤츠 뉴 E클래스 동호회
# 1009            해피리뷰
# 1015   까꿍맘 아기용품 공동구매
# 1023   강북노원도봉성북 육아카페
# 1034  이혼에서 재혼까지/이재모2
#
# [183 rows x 1 columns]

# %%
a=total_ages.values.tolist()

# %%
con_list = ['맘','아지매','임출','엄마','줌마','아가','마더스','마녀','새댁','살림','미수다','댁들','육아','진해댁']
test = '|'.join(con_list)

spac = total_ages[total_ages['채널'].str.contains(test)].index
total_ages.drop(spac,inplace=True)
total_ages
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                   채널
# 4               보배드림
# 18             보배드림2
# 19              뽐뿌 3
# 29            레몬테라스2
# 31              뽐뿌 5
# ...              ...
# 958          공황장애 완치
# 974         K3 매니아클럽
# 1002   벤츠 뉴 E클래스 동호회
# 1009            해피리뷰
# 1034  이혼에서 재혼까지/이재모2
#
# [67 rows x 1 columns]

# %% [markdown]
# ### 여성

# %%
path = '/content/drive/Shareddrives/흐사드/가공데이터/sometrend_제외어_및_포함어_원문/아로나민골드_원문_최종/'

list_of_female = [] # 빈 list를 만듦.

for fname in female:
  a=path + fname
  df_temp = pd.read_excel(a,sheet_name = '원문 - 커뮤니티')
  list_of_female.append(df_temp) # 매 Loop에서 취해진 DataFrame을 위의 list에 적재함.
df_female= pd.concat(list_of_female,axis = 0, ignore_index = True) # list 속 DataFrame들을 일괄 병합함.

# %%
# df_female.to_excel('여성.xlsx')

# %%
len(df_female)
# Out:
# 944

# %%
df_female = df_female.drop(['제목'], axis = 1)
df_female = df_female.drop(['작성자'], axis = 1)
df_female = df_female.drop(['URL'], axis = 1)
df_female = df_female.drop(['No.'], axis = 1)
df_female = df_female.drop(['날짜'], axis = 1)

# %%
df_female=df_female.dropna()
df_female
# Out:
#             채널
# 0     당진엄마들의모임
# 1      광주맘 수다방
# 2      카페파우더룸3
# 3    목포맘들의 수다방
# 4       대구맘365
# ..         ...
# 939    창원 줌마렐라
# 940        파주맘
# 941     세종맘모여라
# 942  인천맘의 아띠아모
# 943    카페파우더룸3
#
# [944 rows x 1 columns]

# %%
df_female['채널'].value_counts()
# Out:
# 인천맘의 아띠아모        47
# 레몬테라스            43
# 카페파우더룸3          38
# 수원맘 모여라          37
# 부산맘 아기사랑         32
#                  ..
# 네티즌 성형 토론 카페      1
# 맘이 베베             1
# 해피 고성맘            1
# 부안맘스홀릭            1
# 강북노원도봉성북 육아카페     1
# Name: 채널, Length: 145, dtype: int64

# %%
type(df_female)
# Out:
# pandas.core.frame.DataFrame

# %%
total_female=df_female
total_female=total_female.drop_duplicates()
total_female
# Out:
#                 채널
# 0         당진엄마들의모임
# 1          광주맘 수다방
# 2          카페파우더룸3
# 3        목포맘들의 수다방
# 4           대구맘365
# ..             ...
# 821        김해 줌마렐라
# 857       창원지역맘스베베
# 889            더쿠4
# 900  까꿍맘 아기용품 공동구매
# 910  강북노원도봉성북 육아카페
#
# [145 rows x 1 columns]

# %%
con_list = ['맘','아지매','임출','엄마','줌마','아가','마더스','마녀','새댁','살림','미수다','댁들','육아','진해댁']
test = '|'.join(con_list)

spac = total_female[total_female['채널'].str.contains(test)].index
total_female.drop(spac,inplace=True)
total_female
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                채널
# 2         카페파우더룸3
# 5          유방암이야기
# 19         레몬테라스2
# 44          레몬테라스
# 58         레몬테라스3
# 71         82cook
# 84           도담도담
# 85      웨딩공부(네이버)
# 94           여우야2
# 95            뷰티룸
# 113       카페파우더룸2
# 137            더쿠
# 174      엽기 혹은 진실
# 218         인스티즈3
# 281        예쁜카페예카
# 307       우아한 갱년기
# 310         인스티즈2
# 353        레몬테라스4
# 358        네이트 판2
# 370    프로방스 집 꾸미기
# 482     맛의진미 요리천국
# 514  네티즌 성형 토론 카페
# 565         마이민트2
# 591         행복한여왕
# 599     다이렉트 결혼준비
# 612        신부의 자격
# 637           더쿠2
# 807           피부인
# 889           더쿠4

# %%
len(total_female)
# Out:
# 29

# %%
f=total_female.values.tolist()

# %%
type(f)
# Out:
# list

# %% [markdown]
# total_female = 맘X
#
# df_female = 원본

# %% [markdown]
# ### 여성

# %%
for i in df_female:
  for j in total_female['채널']:
    spac = df_female[df_female['채널'].str.contains(j)].index
    df_female.drop(spac,inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
female_mom.head()
# Out:
#           채널
# 0   당진엄마들의모임
# 1    광주맘 수다방
# 3  목포맘들의 수다방
# 4     대구맘365
# 6  전주 전북 알뜰맘

# %%
len(female_mom)
# Out:
# 754

# %%
len(df_female)
# Out:
# 944

# %%
len(total_female)
# Out:
# 29

# %%
p = []
for i in f:
  if i in a:
    p.append(i)

# %%
len(p)
# Out:
# 9

# %%
p
# Out:
# [['레몬테라스2'],
#  ['레몬테라스'],
#  ['도담도담'],
#  ['여우야2'],
#  ['레몬테라스4'],
#  ['네이트 판2'],
#  ['맛의진미 요리천국'],
#  ['마이민트2'],
#  ['행복한여왕']]
